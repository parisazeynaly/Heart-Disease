# %% [markdown]
# <a href="https://colab.research.google.com/github/parisazeynaly/Heart-Disease/blob/main/Heart_Disease_Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('heart_disease2_modified.csv')

# %%
data
# Out:
#       Unnamed: 0  Gender  age currentSmoker  cigsPerDay BPMeds  \
# 0              0    Male   39            no         0.0     no
# 1              1  Female   46            no         0.0     no
# 2              2    Male   48           yes        20.0     no
# 3              3  Female   61           yes        30.0     no
# 4              4  Female   46           yes        23.0     no
# ...          ...     ...  ...           ...         ...    ...
# 4233        4233    Male   50           yes         1.0     no
# 4234        4234    Male   51           yes        43.0     no
# 4235        4235  Female   48           yes        20.0     no
# 4236        4236  Female   44           yes        15.0     no
# 4237        4237  Female   52            no         0.0     no
#
#      prevalentStroke prevalentHyp diabetes  totChol  sysBP  diaBP    BMI  \
# 0                 no           no       no    195.0  106.0   70.0  26.97
# 1                 no           no       no    250.0  121.0   81.0  28.73
# 2                 no           no       no    245.0  127.5   80.0  25.34
# 3                 no          yes       no    225.0  150.0   95.0  28.58
# 4                 no           no       no    285.0  130.0   84.0  23.10
# ...              ...          ...      ...      ...    ...    ...    ...
# 4233              no          yes       no    313.0  179.0   92.0  25.97
# 4234              no           no       no    207.0  126.5   80.0  19.71
# 4235              no           no       no    248.0  131.0   72.0  22.00
# 4236              no           no       no    210.0  126.5   87.0  19.16
# 4237              no           no       no    269.0  133.5   83.0  21.47
#
#       heartRate  glucose Heart_ stroke
# 0          80.0     77.0            No
# 1          95.0     76.0            No
# 2          75.0     70.0            No
# 3          65.0    103.0           yes
# 4          85.0     85.0            No
# ...         ...      ...           ...
# 4233       66.0     86.0           yes
# 4234       65.0     68.0            No
# 4235       84.0     86.0            No
# 4236       86.0      NaN            No
# 4237       80.0    107.0            No
#
# [4238 rows x 16 columns]

# %%
data.drop(columns=['Unnamed: 0'] , inplace=True)

# %%
data
# Out:
#       Gender  age currentSmoker  cigsPerDay BPMeds prevalentStroke  \
# 0       Male   39            no         0.0     no              no
# 1     Female   46            no         0.0     no              no
# 2       Male   48           yes        20.0     no              no
# 3     Female   61           yes        30.0     no              no
# 4     Female   46           yes        23.0     no              no
# ...      ...  ...           ...         ...    ...             ...
# 4233    Male   50           yes         1.0     no              no
# 4234    Male   51           yes        43.0     no              no
# 4235  Female   48           yes        20.0     no              no
# 4236  Female   44           yes        15.0     no              no
# 4237  Female   52            no         0.0     no              no
#
#      prevalentHyp diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0              no       no    195.0  106.0   70.0  26.97       80.0     77.0
# 1              no       no    250.0  121.0   81.0  28.73       95.0     76.0
# 2              no       no    245.0  127.5   80.0  25.34       75.0     70.0
# 3             yes       no    225.0  150.0   95.0  28.58       65.0    103.0
# 4              no       no    285.0  130.0   84.0  23.10       85.0     85.0
# ...           ...      ...      ...    ...    ...    ...        ...      ...
# 4233          yes       no    313.0  179.0   92.0  25.97       66.0     86.0
# 4234           no       no    207.0  126.5   80.0  19.71       65.0     68.0
# 4235           no       no    248.0  131.0   72.0  22.00       84.0     86.0
# 4236           no       no    210.0  126.5   87.0  19.16       86.0      NaN
# 4237           no       no    269.0  133.5   83.0  21.47       80.0    107.0
#
#      Heart_ stroke
# 0               No
# 1               No
# 2               No
# 3              yes
# 4               No
# ...            ...
# 4233           yes
# 4234            No
# 4235            No
# 4236            No
# 4237            No
#
# [4238 rows x 15 columns]

# %%
data['cigsPerDay']
# Out:
# 0        0.0
# 1        0.0
# 2       20.0
# 3       30.0
# 4       23.0
#         ...
# 4233     1.0
# 4234    43.0
# 4235    20.0
# 4236    15.0
# 4237     0.0
# Name: cigsPerDay, Length: 4238, dtype: float64

# %%
data['cigsPerDay'].count()
# Out:
# 4209

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           4238 non-null   object
#  1   age              4238 non-null   int64
#  2   currentSmoker    4238 non-null   object
#  3   cigsPerDay       4209 non-null   float64
#  4   BPMeds           4238 non-null   object
#  5   prevalentStroke  4238 non-null   object
#  6   prevalentHyp     4238 non-null   object
#  7   diabetes         4238 non-null   object
#  8   totChol          4188 non-null   float64
#  9   sysBP            4238 non-null   float64
#  10  diaBP            4238 non-null   float64
#  11  BMI              4219 non-null   float64
#  12  heartRate        4237 non-null   float64
#  13  glucose          3850 non-null   float64
#  14  Heart_ stroke    4238 non-null   object
# dtypes: float64(7), int64(1), object(7)
# memory usage: 496.8+ KB

# %%
data.dropna(inplace =True)
data.reset_index(inplace=True,drop=True)
data
# Out:
#       Gender  age currentSmoker  cigsPerDay BPMeds prevalentStroke  \
# 0       Male   39            no         0.0     no              no
# 1     Female   46            no         0.0     no              no
# 2       Male   48           yes        20.0     no              no
# 3     Female   61           yes        30.0     no              no
# 4     Female   46           yes        23.0     no              no
# ...      ...  ...           ...         ...    ...             ...
# 3795    Male   68            no         0.0     no              no
# 3796    Male   50           yes         1.0     no              no
# 3797    Male   51           yes        43.0     no              no
# 3798  Female   48           yes        20.0     no              no
# 3799  Female   52            no         0.0     no              no
#
#      prevalentHyp diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0              no       no    195.0  106.0   70.0  26.97       80.0     77.0
# 1              no       no    250.0  121.0   81.0  28.73       95.0     76.0
# 2              no       no    245.0  127.5   80.0  25.34       75.0     70.0
# 3             yes       no    225.0  150.0   95.0  28.58       65.0    103.0
# 4              no       no    285.0  130.0   84.0  23.10       85.0     85.0
# ...           ...      ...      ...    ...    ...    ...        ...      ...
# 3795          yes       no    176.0  168.0   97.0  23.14       60.0     79.0
# 3796          yes       no    313.0  179.0   92.0  25.97       66.0     86.0
# 3797           no       no    207.0  126.5   80.0  19.71       65.0     68.0
# 3798           no       no    248.0  131.0   72.0  22.00       84.0     86.0
# 3799           no       no    269.0  133.5   83.0  21.47       80.0    107.0
#
#      Heart_ stroke
# 0               No
# 1               No
# 2               No
# 3              yes
# 4               No
# ...            ...
# 3795           yes
# 3796           yes
# 3797            No
# 3798            No
# 3799            No
#
# [3800 rows x 15 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3800 entries, 0 to 3799
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           3800 non-null   object
#  1   age              3800 non-null   int64
#  2   currentSmoker    3800 non-null   object
#  3   cigsPerDay       3800 non-null   float64
#  4   BPMeds           3800 non-null   object
#  5   prevalentStroke  3800 non-null   object
#  6   prevalentHyp     3800 non-null   object
#  7   diabetes         3800 non-null   object
#  8   totChol          3800 non-null   float64
#  9   sysBP            3800 non-null   float64
#  10  diaBP            3800 non-null   float64
#  11  BMI              3800 non-null   float64
#  12  heartRate        3800 non-null   float64
#  13  glucose          3800 non-null   float64
#  14  Heart_ stroke    3800 non-null   object
# dtypes: float64(7), int64(1), object(7)
# memory usage: 445.4+ KB

# %% [markdown]
# Converting Gender , prevalentStroke & Heart_ stroke columns to numerical

# %%
data['Gender']=data['Gender'].replace({'Female':0,'Male':1})
data['currentSmoker'] = data['currentSmoker'].replace(['yes','no'],[1,0])
data['BPMeds'] = data['BPMeds'].replace(['yes','no'],[1,0])
data['prevalentHyp'] = data['prevalentHyp'].replace(['yes','no'],[1,0])
data['diabetes'] = data['diabetes'].replace(['yes','no'],[1,0])
data['prevalentStroke'] = data['prevalentStroke'].replace(['yes','no'],[1,0])
data['Heart_ stroke'] = data['Heart_ stroke'].replace(['yes','No'],[1,0])
# Out:
# <ipython-input-18-19295b8382a4>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Gender']=data['Gender'].replace({'Female':0,'Male':1})
# <ipython-input-18-19295b8382a4>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['currentSmoker'] = data['currentSmoker'].replace(['yes','no'],[1,0])
# <ipython-input-18-19295b8382a4>:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['BPMeds'] = data['BPMeds'].replace(['yes','no'],[1,0])
# <ipython-input-18-19295b8382a4>:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['prevalentHyp'] = data['prevalentHyp'].replace(['yes','no'],[1,0])
# <ipython-input-18-19295b8382a4>:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['diabetes'] = data['diabetes'].replace(['yes','no'],[1,0])
# <ipython-input-18-19295b8382a4>:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['prevalentStroke'] = data['prevalentStroke'].replace(['yes','no'],[1,0])
# <ipython-input-18-19295b8382a4>:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Heart_ stroke'] = data['Heart_ stroke'].replace(['yes','No'],[1,0])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3800 entries, 0 to 3799
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           3800 non-null   int64
#  1   age              3800 non-null   int64
#  2   currentSmoker    3800 non-null   int64
#  3   cigsPerDay       3800 non-null   float64
#  4   BPMeds           3800 non-null   int64
#  5   prevalentStroke  3800 non-null   int64
#  6   prevalentHyp     3800 non-null   int64
#  7   diabetes         3800 non-null   int64
#  8   totChol          3800 non-null   float64
#  9   sysBP            3800 non-null   float64
#  10  diaBP            3800 non-null   float64
#  11  BMI              3800 non-null   float64
#  12  heartRate        3800 non-null   float64
#  13  glucose          3800 non-null   float64
#  14  Heart_ stroke    3800 non-null   int64
# dtypes: float64(7), int64(8)
# memory usage: 445.4 KB

# %%
data
# Out:
#       Gender  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0          1   39              0         0.0       0                0
# 1          0   46              0         0.0       0                0
# 2          1   48              1        20.0       0                0
# 3          0   61              1        30.0       0                0
# 4          0   46              1        23.0       0                0
# ...      ...  ...            ...         ...     ...              ...
# 3795       1   68              0         0.0       0                0
# 3796       1   50              1         1.0       0                0
# 3797       1   51              1        43.0       0                0
# 3798       0   48              1        20.0       0                0
# 3799       0   52              0         0.0       0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# 0                0         0    195.0  106.0   70.0  26.97       80.0
# 1                0         0    250.0  121.0   81.0  28.73       95.0
# 2                0         0    245.0  127.5   80.0  25.34       75.0
# 3                1         0    225.0  150.0   95.0  28.58       65.0
# 4                0         0    285.0  130.0   84.0  23.10       85.0
# ...            ...       ...      ...    ...    ...    ...        ...
# 3795             1         0    176.0  168.0   97.0  23.14       60.0
# 3796             1         0    313.0  179.0   92.0  25.97       66.0
# 3797             0         0    207.0  126.5   80.0  19.71       65.0
# 3798             0         0    248.0  131.0   72.0  22.00       84.0
# 3799             0         0    269.0  133.5   83.0  21.47       80.0
#
#       glucose  Heart_ stroke
# 0        77.0              0
# 1        76.0              0
# 2        70.0              0
# 3       103.0              1
# 4        85.0              0
# ...       ...            ...
# 3795     79.0              1
# 3796     86.0              1
# 3797     68.0              0
# 3798     86.0              0
# 3799    107.0              0
#
# [3800 rows x 15 columns]

# %%
data['currentSmoker'].count()
# Out:
# 3800
